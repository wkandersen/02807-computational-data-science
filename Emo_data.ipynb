# %%
import pandas as pd

# %%
df_emo = pd.read_csv('NRC-Emotion-Lexicon-Wordlevel-v0.92.txt', sep='\t', header=None, names=['word', 'emotion', 'association'])
df_emo.head()
# Out:
#     word       emotion  association
# 0  aback         anger            0
# 1  aback  anticipation            0
# 2  aback       disgust            0
# 3  aback          fear            0
# 4  aback           joy            0

# %%
df_emo['emotion'].value_counts()
# Out:
# anger           14154
# anticipation    14154
# disgust         14154
# fear            14154
# joy             14154
# negative        14154
# positive        14154
# sadness         14154
# surprise        14154
# trust           14154
# Name: emotion, dtype: int64
